# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# Abrimos el archivo en un data frame

# %%
import pandas as pd

# Lee el archivo txt en un DataFrame
df = pd.read_csv('../Business Context/data.txt')  # Puedes especificar el delimitador según sea necesario

df
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %% [markdown]
# # actual_productivity fuera del rango [0:1]

# %%
df[df.actual_productivity >= 1]
# Out:
#           date   quarter  department        day  team  targeted_productivity  \
# 337  1/20/2015  Quarter3  finishing     Tuesday     5                   0.70
# 437  1/26/2015  Quarter4  finishing      Monday     3                   0.75
# 456  1/27/2015  Quarter4      sweing    Tuesday     2                   0.75
# 457  1/27/2015  Quarter4      sweing    Tuesday     3                   0.75
# 477  1/28/2015  Quarter4      sweing  Wednesday     2                   0.80
# 478  1/28/2015  Quarter4      sweing  Wednesday     3                   0.80
# 498  1/29/2015  Quarter5      sweing   Thursday     2                   0.80
# 518  1/31/2015  Quarter5      sweing   Saturday     3                   0.80
# 519  1/31/2015  Quarter5      sweing   Saturday     2                   0.80
# 542   2/1/2015  Quarter1  finishing      Sunday     8                   0.65
# 543   2/1/2015  Quarter1      sweing     Sunday     2                   0.80
# ...

# %% [markdown]
# ## Eliminacion de datos de actual_productivity fuera del rango

# %%
df = df[df['actual_productivity'] <= 1]
df
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
df[df.actual_productivity >= 1]
# Out:
# Empty DataFrame
# Columns: [date, quarter, department, day, team, targeted_productivity, smv, wip, over_time, incentive, idle_time, idle_men, no_of_style_change, no_of_workers, actual_productivity]
# Index: []

# %% [markdown]
# ### Mostrar duplicados y nulos

# %%
def mostrar_duplicados(df):
    """
    Esta función toma un DataFrame de pandas y muestra las filas duplicadas en el DataFrame.
    
    Parámetros:
        - df: DataFrame de pandas
        
    Retorna:
        - DataFrame que contiene las filas duplicadas en el DataFrame de entrada.
    """
    duplicados = df[df.duplicated(keep=False)]
    return duplicados

def mostrar_valores_nulos(df):
    """
    Esta función toma un DataFrame de pandas y muestra los valores nulos en el DataFrame.
    
    Parámetros:
        - df: DataFrame de pandas
        
    Retorna:
        - DataFrame que contiene los valores nulos en el DataFrame de entrada.
    """
    valores_nulos = df[df.isnull().any(axis=1)]
    return valores_nulos

p = mostrar_valores_nulos(df)
p
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 6      1/1/2015  Quarter1  finishing    Thursday     2                   0.75
# 13     1/1/2015  Quarter1  finishing    Thursday    10                   0.65
# 14     1/1/2015  Quarter1  finishing    Thursday     8                   0.75
# 15     1/1/2015  Quarter1  finishing    Thursday     4                   0.75
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %% [markdown]
# No hay valores duplicados, hay varios valores nulos en la variable wip: Trabajo en progreso. Incluye la cantidad de elementos sin terminar.

# %%
df['wip']

max_wip = df['wip'].max()
print(max_wip)

min_wip = df['wip'].min()
print(min_wip)
# Out:
# 23122.0
# 7.0

# %% [markdown]
# Cantidad de departamentos en el modelo

# %%
department_values = df['department'].unique()
print(department_values)

department_counts = df['department'].value_counts()
print(department_counts)
# Out:
# ['sweing' 'finishing ' 'finishing']
# department
# sweing        666
# finishing     253
# finishing     241
# Name: count, dtype: int64

# %% [markdown]
# se observa que hay finishing esta repetido.

# %% [markdown]
# ### Departamentos que tienen nulo la variable wip

# %%
departamentos_con_nulos = df[df['wip'].isnull()]['department'].unique()
print(departamentos_con_nulos)

departamentos_con_nulos = df[df['wip'].isnull()]['department'].value_counts()
print(departamentos_con_nulos)
# Out:
# ['finishing ' 'finishing']
# department
# finishing     253
# finishing     241
# Name: count, dtype: int64

# %% [markdown]
# los valores nuelos estan en el departamento de finishing

# %% [markdown]
# # Se une finishing

# %%
df['department'] = df['department'].replace('finishing ', 'finishing')
# Out:
# C:\Users\hfons\AppData\Local\Temp\ipykernel_12012\2168790283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['department'] = df['department'].replace('finishing ', 'finishing')

# %%
df["department"].unique()
# Out:
# array(['sweing', 'finishing'], dtype=object)

# %% [markdown]
# ## Remplazar valores nulos por 0

# %%
def reemplazar_nulos(df, valor_reemplazo=0):
    """
    Esta función toma un DataFrame de pandas y reemplaza los valores nulos con un valor especificado.
    
    Parámetros:
        - df: DataFrame de pandas
        - valor_reemplazo: Valor con el que se reemplazarán los valores nulos (por defecto es "N/A")
        
    Retorna:
        - DataFrame con los valores nulos reemplazados.
    """
    df_reemplazado = df.fillna(valor_reemplazo)
    return df_reemplazado

df = reemplazar_nulos(df)

df.count()
# Out:
# date                     1160
# quarter                  1160
# department               1160
# day                      1160
# team                     1160
# targeted_productivity    1160
# smv                      1160
# wip                      1160
# over_time                1160
# incentive                1160
# idle_time                1160
# idle_men                 1160
# no_of_style_change       1160
# no_of_workers            1160
# actual_productivity      1160
# dtype: int64

# %% [markdown]
# se observa si el formato de la fecha esta bien y si como esta formado

# %%
import pandas as pd

# Intentar convertir la columna de fecha a un objeto de fecha
try:
    df['date'] = pd.to_datetime(df['date'])
    print("El formato de fecha es correcto.")
except ValueError:
    print("El formato de fecha es incorrecto.")

fecha = df['date'].iloc[0]
if fecha.day < 13:
    formato = "mes-día"
else:
    formato = "día-mes"
print("El formato de fecha es:", formato)
# Out:
# El formato de fecha es correcto.
# El formato de fecha es: mes-día

# %% [markdown]
# ## Datos atipicos de "incentive"

# %%
df = df[df['incentive'] <= 130]
df.count()
# Out:
# date                     1150
# quarter                  1150
# department               1150
# day                      1150
# team                     1150
# targeted_productivity    1150
# smv                      1150
# wip                      1150
# over_time                1150
# incentive                1150
# idle_time                1150
# idle_men                 1150
# no_of_style_change       1150
# no_of_workers            1150
# actual_productivity      1150
# dtype: int64

# %% [markdown]
# # Descargamos los datos limpios

# %%
df.to_csv("datoslimpios.csv", index=False)
